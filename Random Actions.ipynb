# %%
import gym
import gym_graph
# %matplotlib inline

# %%
env =gym.make("graph-v0")
# Out:
# [2018-05-16 22:29:24,011] Making new env: graph-v0
# imported libraries
# Navigation Environment - Version 0.1.0

# %%
env.reset()
# env.render()
REWARD = 0
for _ in range(1000):
#     env.render()
    obs, reward, done, other = env.step(env.action_space.sample()) # take a random action
    REWARD += reward
    print "\t Cumulative reward = ", REWARD
# Out:
# [179.9987084349087, 0.0, 0, 0.0035570000000006985, <dictionary-keyiterator object at 0x10f34e100>, None, None, None, None, None, None, None, None, 79.345, u'residential', 0, 137.99974099819863, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# 	 Cumulative reward =  -10
# [179.9987084349087, 0.0, 0, 0.0035570000000006985, <dictionary-keyiterator object at 0x10f34e1b0>, None, None, None, None, None, None, None, None, 79.345, u'residential', 0, 137.99974099819863, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# 	 Cumulative reward =  -20
# ...
